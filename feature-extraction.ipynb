# %%
import pandas as pd
import pickle
import numpy as np

# %%
df = pickle.load(open('dataset2.pkl','rb'))

# %%
df

# The below features are required
# batting_team
# bowling team
# city
# current score
# ball left
# wickets left
# current rr
# last five
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed     city  \
# 0           2    Australia    Sri Lanka   0.1     0                0      NaN
# 1           2    Australia    Sri Lanka   0.2     0                0      NaN
# 2           2    Australia    Sri Lanka   0.3     1                0      NaN
# 3           2    Australia    Sri Lanka   0.4     2                0      NaN
# 4           2    Australia    Sri Lanka   0.5     0                0      NaN
# ..        ...          ...          ...   ...   ...              ...      ...
# 121       964    Sri Lanka    Australia  19.3     1                0  Colombo
# 122       964    Sri Lanka    Australia  19.4     0                0  Colombo
# 123       964    Sri Lanka    Australia  19.5     0      DM de Silva  Colombo
# 124       964    Sri Lanka    Australia  19.6     2                0  Colombo
# 125       964    Sri Lanka    Australia  19.7     1                0  Colombo
#
#                         venue
# 0    Melbourne Cricket Ground
# 1    Melbourne Cricket Ground
# 2    Melbourne Cricket Ground
# 3    Melbourne Cricket Ground
# 4    Melbourne Cricket Ground
# ..                        ...
# 121       R Premadasa Stadium
# 122       R Premadasa Stadium
# 123       R Premadasa Stadium
# 124       R Premadasa Stadium
# 125       R Premadasa Stadium
#
# [63888 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# match_id               0
# batting_team           0
# bowling_team           0
# ball                   0
# runs                   0
# player_dismissed       0
# city                8548
# venue                  0
# dtype: int64

# %%
df[df['city'].isnull()]['venue'].value_counts()
# Out:
# venue
# Dubai International Cricket Stadium        2969
# Pallekele International Cricket Stadium    2066
# Melbourne Cricket Ground                   1453
# Sydney Cricket Ground                       749
# Adelaide Oval                               498
# Harare Sports Club                          372
# Sharjah Cricket Stadium                     249
# Sylhet International Cricket Stadium        128
# Carrara Oval                                 64
# Name: count, dtype: int64

# %%
cities = np.where(df['city'].isnull(),df['venue'].str.split().apply(lambda x:x[0]),df['city'])

# %%
cities
# Out:
# array(['Melbourne', 'Melbourne', 'Melbourne', ..., 'Colombo', 'Colombo',
#        'Colombo'], dtype=object)

# %%
df['city'] = cities

# %%
df.isnull().sum()
# Out:
# match_id            0
# batting_team        0
# bowling_team        0
# ball                0
# runs                0
# player_dismissed    0
# city                0
# venue               0
# dtype: int64

# %%
df.drop(columns=['venue'],inplace=True)

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                0
# 1           2    Australia    Sri Lanka   0.2     0                0
# 2           2    Australia    Sri Lanka   0.3     1                0
# 3           2    Australia    Sri Lanka   0.4     2                0
# 4           2    Australia    Sri Lanka   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 121       964    Sri Lanka    Australia  19.3     1                0
# 122       964    Sri Lanka    Australia  19.4     0                0
# 123       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 124       964    Sri Lanka    Australia  19.6     2                0
# 125       964    Sri Lanka    Australia  19.7     1                0
#
#           city
# 0    Melbourne
# 1    Melbourne
# 2    Melbourne
# 3    Melbourne
# 4    Melbourne
# ..         ...
# 121    Colombo
# 122    Colombo
# 123    Colombo
# 124    Colombo
# 125    Colombo
#
# [63888 rows x 7 columns]

# %%
eligible_cities = df['city'].value_counts()[df['city'].value_counts() > 600].index.tolist()

# %%
df = df[df['city'].isin(eligible_cities)]

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                0
# 1           2    Australia    Sri Lanka   0.2     0                0
# 2           2    Australia    Sri Lanka   0.3     1                0
# 3           2    Australia    Sri Lanka   0.4     2                0
# 4           2    Australia    Sri Lanka   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 121       964    Sri Lanka    Australia  19.3     1                0
# 122       964    Sri Lanka    Australia  19.4     0                0
# 123       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 124       964    Sri Lanka    Australia  19.6     2                0
# 125       964    Sri Lanka    Australia  19.7     1                0
#
#           city
# 0    Melbourne
# 1    Melbourne
# 2    Melbourne
# 3    Melbourne
# 4    Melbourne
# ..         ...
# 121    Colombo
# 122    Colombo
# 123    Colombo
# 124    Colombo
# 125    Colombo
#
# [50501 rows x 7 columns]

# %%
print(df['runs'].dtype)
# Out:
# int64

# %%
df['current_score'] = df.groupby('match_id')['runs'].cumsum()
# Out:
# C:\Users\N I T R O V15\AppData\Local\Temp\ipykernel_7008\190681986.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['current_score'] = df.groupby('match_id')['runs'].cumsum()

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                0
# 1           2    Australia    Sri Lanka   0.2     0                0
# 2           2    Australia    Sri Lanka   0.3     1                0
# 3           2    Australia    Sri Lanka   0.4     2                0
# 4           2    Australia    Sri Lanka   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 121       964    Sri Lanka    Australia  19.3     1                0
# 122       964    Sri Lanka    Australia  19.4     0                0
# 123       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 124       964    Sri Lanka    Australia  19.6     2                0
# 125       964    Sri Lanka    Australia  19.7     1                0
#
#           city  current_score
# 0    Melbourne              0
# 1    Melbourne              0
# 2    Melbourne              1
# 3    Melbourne              3
# 4    Melbourne              3
# ..         ...            ...
# 121    Colombo            125
# 122    Colombo            125
# 123    Colombo            125
# 124    Colombo            127
# 125    Colombo            128
#
# [50501 rows x 8 columns]

# %%
df['over'] = df['ball'].apply(lambda x:str(x).split(".")[0])
df['ball_no'] = df['ball'].apply(lambda x:str(x).split(".")[1])
df
# Out:
# C:\Users\N I T R O V15\AppData\Local\Temp\ipykernel_7008\2777558413.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['over'] = df['ball'].apply(lambda x:str(x).split(".")[0])
# C:\Users\N I T R O V15\AppData\Local\Temp\ipykernel_7008\2777558413.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ball_no'] = df['ball'].apply(lambda x:str(x).split(".")[1])
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                0
# 1           2    Australia    Sri Lanka   0.2     0                0
# 2           2    Australia    Sri Lanka   0.3     1                0
# 3           2    Australia    Sri Lanka   0.4     2                0
# 4           2    Australia    Sri Lanka   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 121       964    Sri Lanka    Australia  19.3     1                0
# 122       964    Sri Lanka    Australia  19.4     0                0
# 123       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 124       964    Sri Lanka    Australia  19.6     2                0
# 125       964    Sri Lanka    Australia  19.7     1                0
#
#           city  current_score over ball_no
# 0    Melbourne              0    0       1
# 1    Melbourne              0    0       2
# 2    Melbourne              1    0       3
# 3    Melbourne              3    0       4
# 4    Melbourne              3    0       5
# ..         ...            ...  ...     ...
# 121    Colombo            125   19       3
# 122    Colombo            125   19       4
# 123    Colombo            125   19       5
# 124    Colombo            127   19       6
# 125    Colombo            128   19       7
#
# [50501 rows x 10 columns]

# %%
df['balls_bowled'] = (df['over'].astype('int')*6) + df['ball_no'].astype('int')
df
# Out:
# C:\Users\N I T R O V15\AppData\Local\Temp\ipykernel_7008\562775579.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_bowled'] = (df['over'].astype('int')*6) + df['ball_no'].astype('int')
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                0
# 1           2    Australia    Sri Lanka   0.2     0                0
# 2           2    Australia    Sri Lanka   0.3     1                0
# 3           2    Australia    Sri Lanka   0.4     2                0
# 4           2    Australia    Sri Lanka   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 121       964    Sri Lanka    Australia  19.3     1                0
# 122       964    Sri Lanka    Australia  19.4     0                0
# 123       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 124       964    Sri Lanka    Australia  19.6     2                0
# 125       964    Sri Lanka    Australia  19.7     1                0
#
#           city  current_score over ball_no  balls_bowled
# 0    Melbourne              0    0       1             1
# 1    Melbourne              0    0       2             2
# 2    Melbourne              1    0       3             3
# 3    Melbourne              3    0       4             4
# 4    Melbourne              3    0       5             5
# ..         ...            ...  ...     ...           ...
# 121    Colombo            125   19       3           117
# 122    Colombo            125   19       4           118
# 123    Colombo            125   19       5           119
# 124    Colombo            127   19       6           120
# 125    Colombo            128   19       7           121
#
# [50501 rows x 11 columns]

# %%
df['balls_left'] = 120 - df['balls_bowled']
# Out:
# C:\Users\N I T R O V15\AppData\Local\Temp\ipykernel_7008\1770127845.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_left'] = 120 - df['balls_bowled']

# %%
df['balls_left'] = df['balls_left'].apply(lambda x:0 if x<0 else x)
df
# Out:
# C:\Users\N I T R O V15\AppData\Local\Temp\ipykernel_7008\3511862288.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['balls_left'] = df['balls_left'].apply(lambda x:0 if x<0 else x)
#      match_id batting_team bowling_team  ball  runs player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                0
# 1           2    Australia    Sri Lanka   0.2     0                0
# 2           2    Australia    Sri Lanka   0.3     1                0
# 3           2    Australia    Sri Lanka   0.4     2                0
# 4           2    Australia    Sri Lanka   0.5     0                0
# ..        ...          ...          ...   ...   ...              ...
# 121       964    Sri Lanka    Australia  19.3     1                0
# 122       964    Sri Lanka    Australia  19.4     0                0
# 123       964    Sri Lanka    Australia  19.5     0      DM de Silva
# 124       964    Sri Lanka    Australia  19.6     2                0
# 125       964    Sri Lanka    Australia  19.7     1                0
#
#           city  current_score over ball_no  balls_bowled  balls_left
# 0    Melbourne              0    0       1             1         119
# 1    Melbourne              0    0       2             2         118
# 2    Melbourne              1    0       3             3         117
# 3    Melbourne              3    0       4             4         116
# 4    Melbourne              3    0       5             5         115
# ..         ...            ...  ...     ...           ...         ...
# 121    Colombo            125   19       3           117           3
# 122    Colombo            125   19       4           118           2
# 123    Colombo            125   19       5           119           1
# 124    Colombo            127   19       6           120           0
# 125    Colombo            128   19       7           121           0
#
# [50501 rows x 12 columns]

# %%
df['player_dismissed'] = df['player_dismissed'].apply(lambda x:0 if x=='0' else 1)
df['player_dismissed'] = df['player_dismissed'].astype('int')
df['player_dismissed'] = df.groupby('match_id')['player_dismissed'].cumsum()
df['wickets_left'] = 10 - df['player_dismissed']
# Out:
# C:\Users\N I T R O V15\AppData\Local\Temp\ipykernel_7008\3929200049.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['player_dismissed'] = df['player_dismissed'].apply(lambda x:0 if x=='0' else 1)
# C:\Users\N I T R O V15\AppData\Local\Temp\ipykernel_7008\3929200049.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['player_dismissed'] = df['player_dismissed'].astype('int')
# C:\Users\N I T R O V15\AppData\Local\Temp\ipykernel_7008\3929200049.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['player_dismissed'] = df.groupby('match_id')['player_dismissed'].cumsum()
# C:\Users\N I T R O V15\AppData\Local\Temp\ipykernel_7008\3929200049.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['wickets_left'] = 10 - df['player_dismissed']

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                 0
# 1           2    Australia    Sri Lanka   0.2     0                 0
# 2           2    Australia    Sri Lanka   0.3     1                 0
# 3           2    Australia    Sri Lanka   0.4     2                 0
# 4           2    Australia    Sri Lanka   0.5     0                 0
# ..        ...          ...          ...   ...   ...               ...
# 121       964    Sri Lanka    Australia  19.3     1                 8
# 122       964    Sri Lanka    Australia  19.4     0                 8
# 123       964    Sri Lanka    Australia  19.5     0                 9
# 124       964    Sri Lanka    Australia  19.6     2                 9
# 125       964    Sri Lanka    Australia  19.7     1                 9
#
#           city  current_score over ball_no  balls_bowled  balls_left  \
# 0    Melbourne              0    0       1             1         119
# 1    Melbourne              0    0       2             2         118
# 2    Melbourne              1    0       3             3         117
# 3    Melbourne              3    0       4             4         116
# 4    Melbourne              3    0       5             5         115
# ..         ...            ...  ...     ...           ...         ...
# 121    Colombo            125   19       3           117           3
# 122    Colombo            125   19       4           118           2
# 123    Colombo            125   19       5           119           1
# 124    Colombo            127   19       6           120           0
# 125    Colombo            128   19       7           121           0
#
#      wickets_left
# 0              10
# 1              10
# 2              10
# 3              10
# 4              10
# ..            ...
# 121             2
# 122             2
# 123             1
# 124             1
# 125             1
#
# [50501 rows x 13 columns]

# %%
df['crr'] = (df['current_score']*6)/df['balls_bowled']
# Out:
# C:\Users\N I T R O V15\AppData\Local\Temp\ipykernel_7008\914577034.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['crr'] = (df['current_score']*6)/df['balls_bowled']

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                 0
# 1           2    Australia    Sri Lanka   0.2     0                 0
# 2           2    Australia    Sri Lanka   0.3     1                 0
# 3           2    Australia    Sri Lanka   0.4     2                 0
# 4           2    Australia    Sri Lanka   0.5     0                 0
# ..        ...          ...          ...   ...   ...               ...
# 121       964    Sri Lanka    Australia  19.3     1                 8
# 122       964    Sri Lanka    Australia  19.4     0                 8
# 123       964    Sri Lanka    Australia  19.5     0                 9
# 124       964    Sri Lanka    Australia  19.6     2                 9
# 125       964    Sri Lanka    Australia  19.7     1                 9
#
#           city  current_score over ball_no  balls_bowled  balls_left  \
# 0    Melbourne              0    0       1             1         119
# 1    Melbourne              0    0       2             2         118
# 2    Melbourne              1    0       3             3         117
# 3    Melbourne              3    0       4             4         116
# 4    Melbourne              3    0       5             5         115
# ..         ...            ...  ...     ...           ...         ...
# 121    Colombo            125   19       3           117           3
# 122    Colombo            125   19       4           118           2
# 123    Colombo            125   19       5           119           1
# 124    Colombo            127   19       6           120           0
# 125    Colombo            128   19       7           121           0
#
#      wickets_left       crr
# 0              10  0.000000
# 1              10  0.000000
# 2              10  2.000000
# 3              10  4.500000
# 4              10  3.600000
# ..            ...       ...
# 121             2  6.410256
# 122             2  6.355932
# 123             1  6.302521
# 124             1  6.350000
# 125             1  6.347107
#
# [50501 rows x 14 columns]

# %%
df['runs'].unique()
# Out:
# array([0, 1, 2, 3, 4, 6, 7, 5], dtype=int64)

# %%
df['runs'] = pd.to_numeric(df['runs'], errors='coerce')
groups = df.groupby('match_id')
match_ids = df['match_id'].unique()
last_five = []


#for id in match_ids:
 #   rolling_sums = groups.get_group(id)['runs'].rolling(window=30).sum()
  #  last_five.extend(rolling_sums.dropna().values.tolist())  

for id in match_ids:
    last_five.extend(groups.get_group(id)['runs'].rolling(window=30).sum().values.tolist())
# Out:
# C:\Users\N I T R O V15\AppData\Local\Temp\ipykernel_7008\3851151098.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['runs'] = pd.to_numeric(df['runs'], errors='coerce')

# %%
last_five
# Out:
# [nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  43.0,
#  44.0,
#  45.0,
#  44.0,
#  42.0,
#  43.0,
#  41.0,
#  41.0,
#  41.0,
#  42.0,
#  42.0,
#  39.0,
#  38.0,
#  39.0,
#  38.0,
#  39.0,
#  40.0,
#  37.0,
#  41.0,
#  42.0,
#  42.0,
#  44.0,
#  44.0,
#  40.0,
#  39.0,
#  37.0,
#  35.0,
#  31.0,
#  27.0,
#  26.0,
#  31.0,
#  31.0,
#  30.0,
#  31.0,
#  31.0,
#  32.0,
#  31.0,
#  31.0,
#  36.0,
#  37.0,
#  37.0,
#  37.0,
#  37.0,
#  36.0,
#  36.0,
#  36.0,
#  36.0,
#  35.0,
#  32.0,
#  32.0,
#  31.0,
#  29.0,
#  29.0,
#  31.0,
#  32.0,
#  32.0,
#  32.0,
#  33.0,
#  36.0,
#  37.0,
#  37.0,
#  39.0,
#  41.0,
#  40.0,
#  41.0,
#  41.0,
#  42.0,
#  44.0,
#  39.0,
#  43.0,
#  45.0,
#  48.0,
#  48.0,
#  48.0,
#  49.0,
#  49.0,
#  49.0,
#  51.0,
#  51.0,
#  51.0,
#  52.0,
#  52.0,
#  53.0,
#  53.0,
#  53.0,
#  54.0,
#  53.0,
#  52.0,
#  50.0,
#  53.0,
#  47.0,
#  46.0,
#  45.0,
#  46.0,
#  47.0,
#  49.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  46.0,
#  52.0,
#  53.0,
#  57.0,
#  58.0,
#  59.0,
#  59.0,
#  59.0,
#  53.0,
#  53.0,
#  54.0,
#  50.0,
#  50.0,
#  49.0,
#  50.0,
#  47.0,
#  48.0,
#  49.0,
#  49.0,
#  46.0,
#  46.0,
#  51.0,
#  48.0,
#  48.0,
#  48.0,
#  44.0,
#  45.0,
#  42.0,
#  43.0,
#  40.0,
#  39.0,
#  39.0,
#  39.0,
#  36.0,
#  35.0,
#  39.0,
#  39.0,
#  38.0,
#  38.0,
#  37.0,
#  37.0,
#  38.0,
#  39.0,
#  41.0,
#  40.0,
#  40.0,
#  39.0,
#  38.0,
#  39.0,
#  42.0,
#  47.0,
#  42.0,
#  45.0,
#  45.0,
#  49.0,
#  49.0,
#  48.0,
#  47.0,
#  45.0,
#  45.0,
#  45.0,
#  40.0,
#  41.0,
#  41.0,
#  42.0,
#  37.0,
#  38.0,
#  39.0,
#  43.0,
#  46.0,
#  47.0,
#  47.0,
#  46.0,
#  50.0,
#  56.0,
#  57.0,
#  60.0,
#  59.0,
#  59.0,
#  55.0,
#  51.0,
#  51.0,
#  51.0,
#  53.0,
#  51.0,
#  51.0,
#  52.0,
#  53.0,
#  54.0,
#  53.0,
#  54.0,
#  53.0,
#  52.0,
#  51.0,
#  51.0,
#  51.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  42.0,
#  42.0,
#  43.0,
#  42.0,
#  42.0,
#  43.0,
#  40.0,
#  40.0,
#  37.0,
#  33.0,
#  33.0,
#  33.0,
#  34.0,
#  34.0,
#  35.0,
#  36.0,
#  36.0,
#  37.0,
#  34.0,
#  39.0,
#  35.0,
#  36.0,
#  36.0,
#  33.0,
#  33.0,
#  34.0,
#  34.0,
#  35.0,
#  34.0,
#  35.0,
#  41.0,
#  43.0,
#  41.0,
#  42.0,
#  43.0,
#  42.0,
#  42.0,
#  42.0,
#  42.0,
#  42.0,
#  42.0,
#  47.0,
#  50.0,
#  51.0,
#  52.0,
#  57.0,
#  53.0,
#  58.0,
#  61.0,
#  59.0,
#  65.0,
#  68.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  70.0,
#  74.0,
#  73.0,
#  68.0,
#  67.0,
#  66.0,
#  66.0,
#  66.0,
#  70.0,
#  70.0,
#  71.0,
#  71.0,
#  72.0,
#  74.0,
#  69.0,
#  65.0,
#  66.0,
#  64.0,
#  59.0,
#  58.0,
#  53.0,
#  50.0,
#  48.0,
#  43.0,
#  40.0,
#  39.0,
#  39.0,
#  39.0,
#  38.0,
#  41.0,
#  42.0,
#  40.0,
#  40.0,
#  41.0,
#  40.0,
#  41.0,
#  40.0,
#  40.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  36.0,
#  36.0,
#  35.0,
#  35.0,
#  32.0,
#  32.0,
#  32.0,
#  31.0,
#  30.0,
#  30.0,
#  30.0,
#  30.0,
#  30.0,
#  31.0,
#  32.0,
#  31.0,
#  31.0,
#  27.0,
#  27.0,
#  27.0,
#  26.0,
#  27.0,
#  28.0,
#  25.0,
#  21.0,
#  20.0,
#  17.0,
#  18.0,
#  18.0,
#  18.0,
#  18.0,
#  19.0,
#  19.0,
#  19.0,
#  20.0,
#  21.0,
#  25.0,
#  26.0,
#  27.0,
#  28.0,
#  34.0,
#  34.0,
#  34.0,
#  35.0,
#  38.0,
#  40.0,
#  44.0,
#  45.0,
#  45.0,
#  45.0,
#  46.0,
#  51.0,
#  54.0,
#  53.0,
#  53.0,
#  53.0,
#  56.0,
#  56.0,
#  59.0,
#  64.0,
#  70.0,
#  70.0,
#  71.0,
#  69.0,
#  67.0,
#  67.0,
#  63.0,
#  62.0,
#  62.0,
#  67.0,
#  67.0,
#  72.0,
#  73.0,
#  71.0,
#  68.0,
#  68.0,
#  65.0,
#  68.0,
#  68.0,
#  74.0,
#  73.0,
#  69.0,
#  66.0,
#  68.0,
#  74.0,
#  74.0,
#  71.0,
#  76.0,
#  73.0,
#  68.0,
#  62.0,
#  67.0,
#  68.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  41.0,
#  42.0,
#  39.0,
#  43.0,
#  44.0,
#  47.0,
#  51.0,
#  51.0,
#  48.0,
#  44.0,
#  44.0,
#  45.0,
#  46.0,
#  47.0,
#  49.0,
#  49.0,
#  50.0,
#  52.0,
#  54.0,
#  54.0,
#  54.0,
#  55.0,
#  54.0,
#  60.0,
#  61.0,
#  56.0,
#  58.0,
#  58.0,
#  54.0,
#  56.0,
#  57.0,
#  56.0,
#  55.0,
#  52.0,
#  51.0,
#  48.0,
#  45.0,
#  46.0,
#  45.0,
#  45.0,
#  45.0,
#  45.0,
#  45.0,
#  45.0,
#  44.0,
#  43.0,
#  43.0,
#  45.0,
#  44.0,
#  47.0,
#  47.0,
#  46.0,
#  49.0,
#  44.0,
#  43.0,
#  46.0,
#  40.0,
#  38.0,
#  44.0,
#  39.0,
#  39.0,
#  40.0,
#  41.0,
#  40.0,
#  46.0,
#  45.0,
#  45.0,
#  44.0,
#  44.0,
#  44.0,
#  44.0,
#  44.0,
#  47.0,
#  50.0,
#  50.0,
#  50.0,
#  55.0,
#  52.0,
#  51.0,
#  53.0,
#  53.0,
#  53.0,
#  50.0,
#  49.0,
#  50.0,
#  46.0,
#  46.0,
#  50.0,
#  44.0,
#  43.0,
#  44.0,
#  43.0,
#  46.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  33.0,
#  33.0,
#  36.0,
#  36.0,
#  34.0,
#  34.0,
#  35.0,
#  36.0,
#  36.0,
#  36.0,
#  32.0,
#  33.0,
#  32.0,
#  29.0,
#  23.0,
#  23.0,
#  26.0,
#  27.0,
#  27.0,
#  27.0,
#  27.0,
#  26.0,
#  27.0,
#  27.0,
#  27.0,
#  23.0,
#  24.0,
#  25.0,
#  27.0,
#  27.0,
#  28.0,
#  29.0,
#  26.0,
#  27.0,
#  26.0,
#  25.0,
#  25.0,
#  25.0,
#  25.0,
#  25.0,
#  26.0,
#  27.0,
#  27.0,
#  26.0,
#  28.0,
#  28.0,
#  25.0,
#  25.0,
#  25.0,
#  25.0,
#  24.0,
#  25.0,
#  24.0,
#  25.0,
#  25.0,
#  29.0,
#  30.0,
#  29.0,
#  31.0,
#  31.0,
#  31.0,
#  31.0,
#  30.0,
#  29.0,
#  30.0,
#  29.0,
#  34.0,
#  34.0,
#  35.0,
#  35.0,
#  34.0,
#  33.0,
#  38.0,
#  39.0,
#  37.0,
#  38.0,
#  38.0,
#  38.0,
#  37.0,
#  38.0,
#  40.0,
#  43.0,
#  49.0,
#  50.0,
#  51.0,
#  47.0,
#  46.0,
#  52.0,
#  48.0,
#  49.0,
#  49.0,
#  49.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  38.0,
#  39.0,
#  40.0,
#  39.0,
#  39.0,
#  39.0,
#  38.0,
#  42.0,
#  43.0,
#  39.0,
#  38.0,
#  35.0,
#  36.0,
#  36.0,
#  40.0,
#  35.0,
#  38.0,
#  38.0,
#  42.0,
#  41.0,
#  42.0,
#  41.0,
#  41.0,
#  41.0,
#  46.0,
#  43.0,
#  42.0,
#  41.0,
#  43.0,
#  43.0,
#  42.0,
#  41.0,
#  44.0,
#  47.0,
#  48.0,
#  49.0,
#  52.0,
#  49.0,
#  48.0,
#  52.0,
#  53.0,
#  53.0,
#  58.0,
#  58.0,
#  58.0,
#  61.0,
#  58.0,
#  59.0,
#  55.0,
#  57.0,
#  57.0,
#  57.0,
#  61.0,
#  61.0,
#  55.0,
#  58.0,
#  59.0,
#  61.0,
#  56.0,
#  56.0,
#  57.0,
#  58.0,
#  54.0,
#  51.0,
#  54.0,
#  53.0,
#  51.0,
#  52.0,
#  53.0,
#  50.0,
#  49.0,
#  48.0,
#  43.0,
#  48.0,
#  48.0,
#  44.0,
#  43.0,
#  48.0,
#  48.0,
#  45.0,
#  44.0,
#  43.0,
#  41.0,
#  43.0,
#  45.0,
#  47.0,
#  47.0,
#  45.0,
#  45.0,
#  44.0,
#  43.0,
#  42.0,
#  42.0,
#  42.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  37.0,
#  37.0,
#  36.0,
#  36.0,
#  37.0,
#  40.0,
#  40.0,
#  41.0,
#  42.0,
#  39.0,
#  39.0,
#  42.0,
#  43.0,
#  44.0,
#  44.0,
#  44.0,
#  42.0,
#  41.0,
#  41.0,
#  41.0,
#  35.0,
#  31.0,
#  30.0,
#  29.0,
#  27.0,
#  27.0,
#  23.0,
#  23.0,
#  24.0,
#  29.0,
#  29.0,
#  28.0,
#  28.0,
#  28.0,
#  29.0,
#  25.0,
#  25.0,
#  25.0,
#  25.0,
#  25.0,
#  30.0,
#  29.0,
#  29.0,
#  29.0,
#  33.0,
#  33.0,
#  34.0,
#  34.0,
#  35.0,
#  36.0,
#  37.0,
#  41.0,
#  41.0,
#  42.0,
#  46.0,
#  47.0,
#  48.0,
#  47.0,
#  47.0,
#  41.0,
#  41.0,
#  41.0,
#  41.0,
#  42.0,
#  41.0,
#  42.0,
#  42.0,
#  42.0,
#  42.0,
#  42.0,
#  37.0,
#  36.0,
#  37.0,
#  37.0,
#  37.0,
#  37.0,
#  36.0,
#  36.0,
#  36.0,
#  36.0,
#  36.0,
#  33.0,
#  33.0,
#  38.0,
#  36.0,
#  35.0,
#  34.0,
#  35.0,
#  36.0,
#  37.0,
#  36.0,
#  36.0,
#  36.0,
#  35.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  ...]

# %%
df['last_five'] = last_five
# Out:
# C:\Users\N I T R O V15\AppData\Local\Temp\ipykernel_7008\1595651733.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['last_five'] = last_five

# %%
df
# Out:
#      match_id batting_team bowling_team  ball  runs  player_dismissed  \
# 0           2    Australia    Sri Lanka   0.1     0                 0
# 1           2    Australia    Sri Lanka   0.2     0                 0
# 2           2    Australia    Sri Lanka   0.3     1                 0
# 3           2    Australia    Sri Lanka   0.4     2                 0
# 4           2    Australia    Sri Lanka   0.5     0                 0
# ..        ...          ...          ...   ...   ...               ...
# 121       964    Sri Lanka    Australia  19.3     1                 8
# 122       964    Sri Lanka    Australia  19.4     0                 8
# 123       964    Sri Lanka    Australia  19.5     0                 9
# 124       964    Sri Lanka    Australia  19.6     2                 9
# 125       964    Sri Lanka    Australia  19.7     1                 9
#
#           city  current_score over ball_no  balls_bowled  balls_left  \
# 0    Melbourne              0    0       1             1         119
# 1    Melbourne              0    0       2             2         118
# 2    Melbourne              1    0       3             3         117
# 3    Melbourne              3    0       4             4         116
# 4    Melbourne              3    0       5             5         115
# ..         ...            ...  ...     ...           ...         ...
# 121    Colombo            125   19       3           117           3
# 122    Colombo            125   19       4           118           2
# 123    Colombo            125   19       5           119           1
# 124    Colombo            127   19       6           120           0
# 125    Colombo            128   19       7           121           0
#
#      wickets_left       crr  last_five
# 0              10  0.000000        NaN
# 1              10  0.000000        NaN
# 2              10  2.000000        NaN
# 3              10  4.500000        NaN
# 4              10  3.600000        NaN
# ..            ...       ...        ...
# 121             2  6.410256       32.0
# 122             2  6.355932       32.0
# 123             1  6.302521       32.0
# 124             1  6.350000       33.0
# 125             1  6.347107       32.0
#
# [50501 rows x 15 columns]

# %%
final_df = df.groupby('match_id').sum()['runs'].reset_index().merge(df,on='match_id')

# %%
final_df=final_df[['batting_team','bowling_team','city','current_score','balls_left','wickets_left','crr','last_five','runs_x']]

# %%
final_df.dropna(inplace=True)

# %%
final_df.isnull().sum()
# Out:
# batting_team     0
# bowling_team     0
# city             0
# current_score    0
# balls_left       0
# wickets_left     0
# crr              0
# last_five        0
# runs_x           0
# dtype: int64

# %%
final_df = final_df.sample(final_df.shape[0])

# %%
final_df.sample(2)
# Out:
#       batting_team bowling_team    city  current_score  balls_left  \
# 50245   Bangladesh        India  Mirpur            113          35
# 38624    Sri Lanka      England  London             43          85
#
#        wickets_left       crr  last_five  runs_x
# 50245             5  7.976471       49.0     120
# 38624             8  7.371429       34.0     183

# %%
X = final_df.drop(columns=['runs_x'])
y = final_df['runs_x']
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=1)

# %%
X_train
# Out:
#        batting_team bowling_team        city  current_score  balls_left  \
# 33760   West Indies    Australia     Colombo             60          70
# 48161         India   Bangladesh   Bangalore             83          43
# 10344         India   Bangladesh      Nagpur             70          61
# 41038     Sri Lanka  West Indies      Mirpur            108          28
# 28514   New Zealand     Pakistan    Hamilton            185           0
# ...             ...          ...         ...            ...         ...
# 36037     Australia     Pakistan       Dubai             40          74
# 41137  South Africa        India      Mirpur             73          54
# 10827   New Zealand      England    Auckland            119          67
# 2286        England  New Zealand    Hamilton             57          78
# 34762   West Indies  New Zealand  Lauderhill            208           1
#
#        wickets_left        crr  last_five
# 33760             8   7.200000       41.0
# 48161             8   6.467532       35.0
# 10344             8   7.118644       40.0
# 41038             6   7.043478       37.0
# 28514             3   9.250000       68.0
# ...             ...        ...        ...
# 36037             8   5.217391       28.0
# 41137             8   6.636364       28.0
# 10827             8  13.471698       51.0
# 2286              8   8.142857       35.0
# 34762             8  10.487395       73.0
#
# [30781 rows x 8 columns]

# %%
# !pip install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-2.1.1-py3-none-win_amd64.whl.metadata (2.1 kB)
# Requirement already satisfied: numpy in c:\users\n i t r o v15\anaconda3\lib\site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in c:\users\n i t r o v15\anaconda3\lib\site-packages (from xgboost) (1.11.4)
# Downloading xgboost-2.1.1-py3-none-win_amd64.whl (124.9 MB)
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/124.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/124.9 MB 279.3 kB/s eta 0:07:28
#    ---------------------------------------- 0.1/124.9 MB 525.1 kB/s eta 0:03:58
#    ---------------------------------------- 0.2/124.9 MB 958.4 kB/s eta 0:02:11
#    ---------------------------------------- 0.6/124.9 MB 2.2 MB/s eta 0:00:58
#     --------------------------------------- 1.8/124.9 MB 6.2 MB/s eta 0:00:20
#    - -------------------------------------- 4.3/124.9 MB 12.4 MB/s eta 0:00:10
#    - -------------------------------------- 4.9/124.9 MB 14.3 MB/s eta 0:00:09
#    -- ------------------------------------- 6.5/124.9 MB 14.8 MB/s eta 0:00:08
#    -- ------------------------------------- 6.5/124.9 MB 14.8 MB/s eta 0:00:08
#    --- ------------------------------------ 9.9/124.9 MB 18.7 MB/s eta 0:00:07
#    --- ------------------------------------ 11.4/124.9 MB 36.3 MB/s eta 0:00:04
#    ---- ----------------------------------- 12.5/124.9 MB 34.4 MB/s eta 0:00:04
#    ---- ----------------------------------- 12.5/124.9 MB 34.4 MB/s eta 0:00:04
#    ---- ----------------------------------- 14.4/124.9 MB 28.5 MB/s eta 0:00:04
#    ---- ----------------------------------- 15.0/124.9 MB 25.2 MB/s eta 0:00:05
#    ----- ---------------------------------- 16.3/124.9 MB 27.3 MB/s eta 0:00:04
#    ------ --------------------------------- 19.8/124.9 MB 34.4 MB/s eta 0:00:04
#    ------ --------------------------------- 21.0/124.9 MB 31.2 MB/s eta 0:00:04
#    ------- -------------------------------- 22.1/124.9 MB 29.7 MB/s eta 0:00:04
#    ------- -------------------------------- 23.8/124.9 MB 34.4 MB/s eta 0:00:03
#    -------- ------------------------------- 25.2/124.9 MB 34.4 MB/s eta 0:00:03
#    -------- ------------------------------- 26.8/124.9 MB 36.4 MB/s eta 0:00:03
#    -------- ------------------------------- 27.4/124.9 MB 31.2 MB/s eta 0:00:04
#    -------- ------------------------------- 28.0/124.9 MB 27.3 MB/s eta 0:00:04
#    --------- ------------------------------ 28.7/124.9 MB 25.1 MB/s eta 0:00:04
#    --------- ------------------------------ 29.4/124.9 MB 23.4 MB/s eta 0:00:05
#    --------- ------------------------------ 29.8/124.9 MB 21.8 MB/s eta 0:00:05
#    --------- ------------------------------ 30.6/124.9 MB 21.1 MB/s eta 0:00:05
#    --------- ------------------------------ 31.1/124.9 MB 19.3 MB/s eta 0:00:05
#    ---------- ----------------------------- 31.5/124.9 MB 19.3 MB/s eta 0:00:05
#    ---------- ----------------------------- 31.8/124.9 MB 17.7 MB/s eta 0:00:06
#    ---------- ----------------------------- 32.1/124.9 MB 16.4 MB/s eta 0:00:06
#    ---------- ----------------------------- 32.4/124.9 MB 16.0 MB/s eta 0:00:06
#    ---------- ----------------------------- 32.9/124.9 MB 14.9 MB/s eta 0:00:07
#    ---------- ----------------------------- 33.2/124.9 MB 14.2 MB/s eta 0:00:07
#    ---------- ----------------------------- 33.6/124.9 MB 13.4 MB/s eta 0:00:07
#    ---------- ----------------------------- 33.9/124.9 MB 12.9 MB/s eta 0:00:08
#    ---------- ----------------------------- 34.1/124.9 MB 12.6 MB/s eta 0:00:08
#    ----------- ---------------------------- 34.4/124.9 MB 11.7 MB/s eta 0:00:08
#    ----------- ---------------------------- 34.8/124.9 MB 11.5 MB/s eta 0:00:08
#    ----------- ---------------------------- 35.1/124.9 MB 10.9 MB/s eta 0:00:09
#    ----------- ---------------------------- 35.5/124.9 MB 10.6 MB/s eta 0:00:09
#    ----------- ---------------------------- 36.0/124.9 MB 10.1 MB/s eta 0:00:09
#    ----------- ---------------------------- 36.5/124.9 MB 9.9 MB/s eta 0:00:09
#    ----------- ---------------------------- 36.9/124.9 MB 9.5 MB/s eta 0:00:10
#    ------------ --------------------------- 37.5/124.9 MB 9.5 MB/s eta 0:00:10
#    ------------ --------------------------- 38.0/124.9 MB 9.5 MB/s eta 0:00:10
#    ------------ --------------------------- 38.4/124.9 MB 9.2 MB/s eta 0:00:10
#    ------------ --------------------------- 38.9/124.9 MB 9.2 MB/s eta 0:00:10
#    ------------ --------------------------- 39.3/124.9 MB 9.0 MB/s eta 0:00:10
#    ------------ --------------------------- 39.8/124.9 MB 9.0 MB/s eta 0:00:10
#    ------------ --------------------------- 40.3/124.9 MB 9.0 MB/s eta 0:00:10
#    ------------- -------------------------- 40.7/124.9 MB 8.8 MB/s eta 0:00:10
#    ------------- -------------------------- 41.2/124.9 MB 8.7 MB/s eta 0:00:10
#    ------------- -------------------------- 41.8/124.9 MB 8.8 MB/s eta 0:00:10
#    ------------- -------------------------- 42.2/124.9 MB 9.2 MB/s eta 0:00:09
#    ------------- -------------------------- 42.8/124.9 MB 9.4 MB/s eta 0:00:09
#    ------------- -------------------------- 43.3/124.9 MB 9.5 MB/s eta 0:00:09
#    -------------- ------------------------- 43.9/124.9 MB 9.8 MB/s eta 0:00:09
#    -------------- ------------------------- 44.4/124.9 MB 10.2 MB/s eta 0:00:08
#    -------------- ------------------------- 45.0/124.9 MB 10.4 MB/s eta 0:00:08
#    -------------- ------------------------- 45.5/124.9 MB 10.9 MB/s eta 0:00:08
#    -------------- ------------------------- 46.0/124.9 MB 10.9 MB/s eta 0:00:08
#    -------------- ------------------------- 46.6/124.9 MB 10.9 MB/s eta 0:00:08
#    --------------- ------------------------ 47.1/124.9 MB 10.9 MB/s eta 0:00:08
#    --------------- ------------------------ 47.7/124.9 MB 11.1 MB/s eta 0:00:07
#    --------------- ------------------------